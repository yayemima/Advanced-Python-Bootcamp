# %%
import json

# %%
with open('montgomery_county_traffic_violation.json', 'r') as read_file:
    data = json.load(read_file)
data
# Out:
# {'data': [[2118167,
#    'EE8BC302-660F-48C4-B422-17427ECE821F',
#    2118167,
#    1482239054,
#    '498050',
#    1482239054,
#    '498050',
#    None,
#    '2013-09-24T00:00:00',
#    '17:11:00',
#    'MCP',
#    '3rd district, Silver Spring',
#    'DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION',
#    '8804 FLOWER AVE',
#    None,
#    None,
#    'No',
#    'No',
#    'No',
#    'No',
#    'No',
#    'No',
#    'No',
#    'No',
#    'No',
#    'No',
#    'MD',
#    '02 - Automobile',
#    '2008',
#    'FORD',
#    '4S',
#    'BLACK',
#    'Citation',
#    '13-401(h)',
#    'Transportation Article',
#    'No',
#    'BLACK',
#    'M',
#    'TAKOMA PARK',
#    'MD',
#    'MD',
#    'A - Marked Patrol',
#    [None, None, None, None, None]],
#   [3064529,
#    '9763533B-48A3-480A-BB54-1EF8C60849AF',
#    3064529,
#    1504085194,
#    '498050',
#    1504085194,
#    '498050',
#    None,
#    '2017-08-29T00:00:00',
#    '10:19:00',
#    'MCP',
#    '2nd district, Bethesda',
# ...
